# %% [markdown]
# <h1><center>Τεχνικές Εξόρυξης Δεδομένων<br>1ηΆσκηση</center></h1>
# <h2><center> <span style="font-weight:normal">AM</span> 1115201700217 <span style="font-weight:normal">Στεφάνου Ορέστης</span></center><br>
# <center> <span style="font-weight:normal">AM</span> 1115201700203 <span style="font-weight:normal">Λεωνίδας Εφραίμ</span></center></h2>

# %% [markdown]
# #

# %% [markdown]
# # 1.1 O πιο συχνός τύπος  room_type

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  4 15:06:33 2020

@author: leonidas
"""

import numpy as np
import pandas as pd #panda 
import glob

df=pd.DataFrame()
Location = r'/home/leonidas/Desktop/datamining python ergasia1/train.csv'
df=pd.read_csv(Location,low_memory=False)

room_type1=df.groupby(['room_type']).size().reset_index(name='counts')
room_type1.sort_values(by='counts',ascending=False)
ax=room_type1.plot(kind='barh',x='room_type',y='counts',title='Oι τύποι δωματίων',legend=False)
ax.yaxis.set_label_text("")
room_type1=room_type1.head(1)
print("O πιο συχνός τύπος τύπος δωματίου",room_type1["room_type"].to_string(index=False, header=False))
# Out:
# O πιο συχνός τύπος τύπος δωματίου  Entire home/apt

# %% [markdown]
# # 1.2 Πορεία τιμών στο διάστημα 3 μηνών

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

from pandas import DataFrame,read_csv

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')

#FIND AVERAGE PRICE FROM EACH MONTH

df=pd.DataFrame()

Location = r'/home/orestis/EKPA/6examino/DataMining/project1/train.csv'
df=pd.read_csv(Location)


months_list = df['Month']
price_list=[]

for x in df['price']:
    try:
        price_list.append(float(x.strip(x[0])))
    except:
        price_list.append(0.0)


months = df['Month'].unique()
months_dict={}
#Create the dictionary where we have for each month how many records we have and the sum of prices
for x in months:
    months_dict[x]=[0,0]

for i in range(0,len(months_list)):
    months_dict[months_list[i]][0]+=1
    months_dict[months_list[i]][1]+=price_list[i]

avg_price_list=[]
for x in months_dict.values():
    avg_price_list.append(x[1]/x[0])

dataset = list(zip(months,avg_price_list))
new_df=pd.DataFrame(data=dataset,columns=['Month','AvgPrice'])
new_df['AvgPrice'].plot()

# %% [markdown]
# # 1.3 Oι 5 πρώτες γειτονιές με τις περισσότερες κριτικές

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  4 15:06:33 2020

@author: leonidas
"""

import numpy as np
import pandas as pd #panda 
import glob
import matplotlib.pyplot as plt
from IPython import get_ipython
import operator
get_ipython().run_line_magic('matplotlib', 'inline')

df=pd.DataFrame()
Location = r'/home/leonidas/Desktop/datamining python ergasia1/train.csv'
df=pd.read_csv(Location,low_memory=False)


neighbourhood=df.groupby(['neighbourhood_cleansed']).sum()
neighbourhood=neighbourhood.filter(['neighbourhood_cleansed', 'number_of_reviews'])
neighbourhood=neighbourhood.sort_values(by='number_of_reviews',ascending=False)
neighbourhood=neighbourhood.head(5)
ax=neighbourhood.plot(kind='barh',title='Οι 5 πρώτες γειτονιές με τις περισσότερες κριτικές',legend=False)
ax.yaxis.set_label_text("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# # 1.4 Γειτονιά με τις περισσότερες καταχωρήσεις ακινήτων

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
from pandas import DataFrame,read_csv

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

#from IPython import get_ipython
#get_ipython().run_line_magic('matplotlib', 'inline')


df=pd.DataFrame()

Location = r'/home/orestis/Desktop/train.csv'
df=pd.read_csv(Location)

all_hoods=df['neighbourhood_cleansed']
hoods=df['neighbourhood_cleansed'].unique()

akinita_dict={}
ids = df['id']

for x in hoods:
    akinita_dict[x]=[]

for i in range(0,len(all_hoods)):
    if(ids[i] not in akinita_dict[all_hoods[i]]):
        akinita_dict[all_hoods[i]].append(ids[i])
    
#Create a list with just the counter of each neighbourhood
akinita_counter=[]
for x in hoods:
    akinita_counter.append(len(akinita_dict[x]))


DataSet = list(zip(hoods,akinita_counter))

new_df=pd.DataFrame(data=DataSet,columns=['hood','akinita'])
new_df['akinita'].plot.bar()

print("Neighbourhood with most estates:")
new_df.sort_values(by='akinita',ascending=False)
# Out:
# Neighbourhood with most estates:
#                                 hood  akinita
# 1             ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ     1585
# 11               ΚΟΥΚΑΚΙ-ΜΑΚΡΥΓΙΑΝΝΗ      846
# 16          ΜΟΥΣΕΙΟ-ΕΞΑΡΧΕΙΑ-ΝΕΑΠΟΛΗ      835
# 20                       ΝΕΟΣ ΚΟΣΜΟΣ      745
# 7   ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ      650
# 3                           ΠΑΓΚΡΑΤΙ      498
# 5                    ΠΛΑΤΕΙΑ ΑΤΤΙΚΗΣ      468
# 15                          ΚΟΛΩΝΑΚΙ      391
# 0                        ΑΜΠΕΛΟΚΗΠΟΙ      383
# 23                          ΑΚΡΟΠΟΛΗ      359
# 21                            ΘΗΣΕΙΟ      318
# 24                         ΠΕΤΡΑΛΩΝΑ      299
# 4                             ΚΥΨΕΛΗ      287
# 2                         ΚΕΡΑΜΕΙΚΟΣ      255
# 6                             ΣΤΑΔΙΟ      241
# 14                            ΙΛΙΣΙΑ      218
# 35                             ΓΟΥΔΙ      146
# 29                        ΛΥΚΑΒΗΤΤΟΣ      142
# 10                  ΠΛΑΤΕΙΑ ΑΜΕΡΙΚΗΣ      128
# ...

# %% [markdown]
# # 1.5 Οι καταχωρήσεις ανά γειτονιά και ανά μήνα

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  4 15:06:33 2020

@author: leonidas
"""

import numpy as np
import pandas as pd #panda 
import glob
import matplotlib.pyplot as plt
from IPython import get_ipython
import operator
get_ipython().run_line_magic('matplotlib', 'inline')

columns=['id','zipcode','transit','bedrooms','beds','review_scores_rating','number_of_reviews','neighbourhood_cleansed',
         'neighbourhood_group_cleansed','name','latitude','longitude','last_review','instant_bookable','host_since',
         'host_response_rate','host_identity_verified','host_has_profile_pic','first_review','description','city',
         'cancellation_policy','bed_type','bathrooms','accommodates','amenities','room_type','property_type','price',
         'availability_365','minimum_nights']

april_df=pd.DataFrame()
Location = r'/home/leonidas/Desktop/datamining python ergasia1/data/april/listings.csv'
april_df=pd.read_csv(Location,low_memory=False)


for x in april_df:
    if x not in columns:
        del april_df[x]



febrouary_df=pd.DataFrame()
Location = r'/home/leonidas/Desktop/datamining python ergasia1/data/febrouary/listings.csv'
febrouary_df=pd.read_csv(Location,low_memory=False)

for x in febrouary_df:
    if x not in columns:
        del febrouary_df[x]



march_df=pd.DataFrame()
Location = r'/home/leonidas/Desktop/datamining python ergasia1/data/march/listings.csv'
march_df=pd.read_csv(Location, low_memory=False)

for x in march_df:
    if x not in columns:
        del march_df[x]




febrouary_df=febrouary_df.groupby(['neighbourhood_cleansed']).size().reset_index(name='February')
march_df=march_df.groupby(['neighbourhood_cleansed']).size().reset_index(name='counts')
april_df=april_df.groupby(['neighbourhood_cleansed']).size().reset_index(name='counts')

febrouary_df['March']=march_df['counts']
febrouary_df['April']=april_df['counts']
df=febrouary_df
df["Total"] = df.sum(axis=1)
print(df)
# Out:
#               neighbourhood_cleansed  February  March  April  Total
# 0                     1Ο ΝΕΚΡΟΤΑΦΕΙΟ        42     43     41    126
# 1                   ΑΓΙΟΣ ΕΛΕΥΘΕΡΙΟΣ        32     34     28     94
# 2   ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ       571    603    607   1781
# 3                     ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ        54     60     63    177
# 4                  ΑΚΑΔΗΜΙΑ ΠΛΑΤΩΝΟΣ        76     82     83    241
# 5                           ΑΚΡΟΠΟΛΗ       323    327    344    994
# 6                        ΑΜΠΕΛΟΚΗΠΟΙ       338    335    343   1016
# 7                         ΑΝΩ ΚΥΨΕΛΗ        81     87     83    251
# 8                        ΑΝΩ ΠΑΤΗΣΙΑ        71     70     73    214
# 9                          ΒΟΤΑΝΙΚΟΣ        71     75     79    225
# 10                             ΓΚΑΖΙ        75     81     82    238
# 11                             ΓΚΥΖΗ        97    109    108    314
# 12                             ΓΟΥΒΑ        62     58     56    176
# ...

# %% [markdown]
# # 1.6 Ιστόγραμμα της μεταβλητής neighborhood(Average price for each neighbourhood)

# %%
from pandas import DataFrame,read_csv

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

#from IPython import get_ipython
#get_ipython().run_line_magic('matplotlib', 'inline')

#FIND AVERAGE PRICE FROM EACH MONTH

df=pd.DataFrame()

Location = r'/home/orestis/EKPA/6examino/DataMining/project1/train.csv'
df=pd.read_csv(Location)

hoods_list = df['neighbourhood_cleansed']
price_list=[]

for x in df['price']:
    try:
        price_list.append(float(x.strip(x[0])))
    except:
        price_list.append(0.0)

hoods = df['neighbourhood_cleansed'].unique()
hoods_price_dict={}
for x in hoods:
    hoods_price_dict[x]=[0,0]

for i in range(0,len(hoods_list)):
    hoods_price_dict[hoods_list[i]][0]+=1
    hoods_price_dict[hoods_list[i]][1]+=price_list[i]

avg_price_list = []
for x in hoods_price_dict.values():
    avg_price_list.append(x[1]/x[0])

dataset = list(zip(hoods,avg_price_list))
print('Average price for each neighbourhood:')
for i in range(0,len(dataset)):
    print(str(i)+'.'+str(dataset[i][0])+'->'+str(dataset[i][1]))
new_df=pd.DataFrame(data=dataset,columns=['Hoods','AvgPrice'])
new_df.plot.bar()
# Out:
# Average price for each neighbourhood:
# 0.ΑΜΠΕΛΟΚΗΠΟΙ->47.80413385826772
# 1.ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ->88.45539122137404
# 2.ΚΕΡΑΜΕΙΚΟΣ->69.29645390070922
# 3.ΠΑΓΚΡΑΤΙ->51.845748683220464
# 4.ΚΥΨΕΛΗ->40.37150466045273
# 5.ΠΛΑΤΕΙΑ ΑΤΤΙΚΗΣ->41.64801864801865
# 6.ΣΤΑΔΙΟ->58.379464285714285
# 7.ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ->58.12128017967434
# 8.1Ο ΝΕΚΡΟΤΑΦΕΙΟ->56.023809523809526
# 9.ΑΚΑΔΗΜΙΑ ΠΛΑΤΩΝΟΣ->45.62240663900415
# 10.ΠΛΑΤΕΙΑ ΑΜΕΡΙΚΗΣ->36.583333333333336
# 11.ΚΟΥΚΑΚΙ-ΜΑΚΡΥΓΙΑΝΝΗ->62.29072253099615
# 12.ΓΟΥΒΑ->46.57954545454545
# 13.ΝΕΑ ΚΥΨΕΛΗ->42.5748502994012
# 14.ΙΛΙΣΙΑ->58.53103448275862
# 15.ΚΟΛΩΝΑΚΙ->79.27798507462687
# 16.ΜΟΥΣΕΙΟ-ΕΞΑΡΧΕΙΑ-ΝΕΑΠΟΛΗ->49.79928475637014
# 17.ΑΝΩ ΚΥΨΕΛΗ->38.342629482071715
# 18.ΒΟΤΑΝΙΚΟΣ->59.74666666666667
# 19.ΑΝΩ ΠΑΤΗΣΙΑ->42.06542056074766
# 20.ΝΕΟΣ ΚΟΣΜΟΣ->53.79588766298897
# 21.ΘΗΣΕΙΟ->77.83916849015317
# 22.ΠΕΔΙΟ ΑΡΕΩΣ->44.86328125
# 23.ΑΚΡΟΠΟΛΗ->89.5814889336016
# 24.ΠΕΤΡΑΛΩΝΑ->45.78651685393258
# 25.ΓΚΥΖΗ->42.69426751592356
# ...

# %% [markdown]
# # 1.7 Πιο συχνός τύπος δωματίου (room_type) σε κάθε γειτονιά

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  4 21:27:55 2020

@author: orestis
"""

from pandas import DataFrame,read_csv

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import operator

from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')


df=pd.DataFrame()

Location = r'/home/orestis/Desktop/train.csv'
df=pd.read_csv(Location)

hoods=df['neighbourhood_cleansed'].unique()
room_types=df['room_type'].unique()

all_hoods=df['neighbourhood_cleansed']
all_room_types=df['room_type']

room_type_counter=[]
for i in range(len(hoods)):
    room_type_counter.append({})
    for x in room_types:
        room_type_counter[i][x]=0

hood_dict={}
for i in range(len(hoods)):
    hood_dict[hoods[i]]=room_type_counter[i]


dataset = list(zip(all_hoods,all_room_types))

for x in dataset:
    hood_dict[x[0]][x[1]]+=1
    
final_data_set=[]

for x in hood_dict:
    most_popular_type=str(max(hood_dict[x].items(), key=operator.itemgetter(1))[0])
    final_data_set.append((x,most_popular_type))

print("Most popular room type at each neighbourhood")
for x in final_data_set:
    print(x[0]+'->'+x[1])
# Out:
# Most popular room type at each neighbourhood
# ΑΜΠΕΛΟΚΗΠΟΙ->Entire home/apt
# ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ->Entire home/apt
# ΚΕΡΑΜΕΙΚΟΣ->Entire home/apt
# ΠΑΓΚΡΑΤΙ->Entire home/apt
# ΚΥΨΕΛΗ->Entire home/apt
# ΠΛΑΤΕΙΑ ΑΤΤΙΚΗΣ->Entire home/apt
# ΣΤΑΔΙΟ->Entire home/apt
# ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ->Entire home/apt
# 1Ο ΝΕΚΡΟΤΑΦΕΙΟ->Entire home/apt
# ΑΚΑΔΗΜΙΑ ΠΛΑΤΩΝΟΣ->Entire home/apt
# ΠΛΑΤΕΙΑ ΑΜΕΡΙΚΗΣ->Entire home/apt
# ΚΟΥΚΑΚΙ-ΜΑΚΡΥΓΙΑΝΝΗ->Entire home/apt
# ΓΟΥΒΑ->Entire home/apt
# ΝΕΑ ΚΥΨΕΛΗ->Entire home/apt
# ΙΛΙΣΙΑ->Entire home/apt
# ΚΟΛΩΝΑΚΙ->Entire home/apt
# ΜΟΥΣΕΙΟ-ΕΞΑΡΧΕΙΑ-ΝΕΑΠΟΛΗ->Entire home/apt
# ΑΝΩ ΚΥΨΕΛΗ->Entire home/apt
# ΒΟΤΑΝΙΚΟΣ->Entire home/apt
# ΑΝΩ ΠΑΤΗΣΙΑ->Entire home/apt
# ΝΕΟΣ ΚΟΣΜΟΣ->Entire home/apt
# ΘΗΣΕΙΟ->Entire home/apt
# ΠΕΔΙΟ ΑΡΕΩΣ->Entire home/apt
# ΑΚΡΟΠΟΛΗ->Entire home/apt
# ΠΕΤΡΑΛΩΝΑ->Entire home/apt
# ΓΚΥΖΗ->Entire home/apt
# ΠΡΟΜΠΟΝΑ->Entire home/apt
# ΓΚΑΖΙ->Entire home/apt
# ΚΟΛΩΝΟΣ->Entire home/apt
# ΛΥΚΑΒΗΤΤΟΣ->Entire home/apt
# ...

# %% [markdown]
# # 1.8 Ο πιο ακριβός τύπος δωματίου

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  4 15:06:33 2020

@author: leonidas
"""

import numpy as np
import pandas as pd #panda 
import glob
import matplotlib.pyplot as plt
from IPython import get_ipython
import operator

get_ipython().run_line_magic('matplotlib', 'inline')
Location = r'/home/leonidas/Desktop/datamining python ergasia1/train.csv'
df=pd.read_csv(Location)


df['price'] = df['price'].replace({'\$':''}, regex = True)
df['price'] = df['price'].replace({',':''}, regex = True)
df.drop(df.columns.difference(['room_type','price']), 1, inplace=True)
df['price'] = df['price'].astype(float)            
df=df.groupby(['room_type']).mean()
df=df.sort_values(by=['price'], ascending=False)

ax=df.plot(kind='barh',title='Oι τύποι δωματίων',legend=False)
ax.yaxis.set_label_text("")

print("O πιο ακριβός τύπος τύπος δωματίου είναι το",df.head(1).index[0])
# Out:
# O πιο ακριβός τύπος τύπος δωματίου είναι το Private room

# %% [markdown]
# # 1.9 Ακινητα Απρίλη και το room type τους

# %%
from pandas import DataFrame,read_csv

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import folium

from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')


df=pd.DataFrame()

Location = r'/home/orestis/EKPA/6examino/DataMining/project1/train.csv'
df=pd.read_csv(Location)

latitude = df['latitude']
longitude = df['longitude']
all_ids = df['id']
months = df['Month']
visited_ids = []

m=folium.Map(location=[latitude[0],longitude[0]])

room_types=df['room_type']

for i in range(0,100):
    if(months[i]=='April' and all_ids[i] not in visited_ids):
        folium.Marker(location=[latitude[i],longitude[i]],popup=room_types[i]).add_to(m)
        visited_ids.append(all_ids[i])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 1.10 Wordclouds με τα δεδομένα από τη στήλη neighbourhood,transit, description, last_review

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  4 15:06:33 2020

@author: leonidas
"""

import numpy as np
import pandas as pd #panda 
import glob
import matplotlib.pyplot as plt
from IPython import get_ipython
import operator
get_ipython().run_line_magic('matplotlib', 'inline')
from subprocess import check_output
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib as mpl
#mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1 


stopwords = set(STOPWORDS)

df=pd.DataFrame()

Location = r'/home/leonidas/Desktop/datamining python ergasia1/train.csv'
df=pd.read_csv(Location,low_memory=False)

neighbourhood=df['neighbourhood_cleansed'].unique()
transit=df['transit'].unique()
description=df['description'].unique()
last_review=df['last_review'].unique()
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(neighbourhood))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(transit))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(last_review))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(description))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # 1.12 Neighbourhoods with best review sccore

# %%
from pandas import DataFrame,read_csv

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import folium

from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')


df=pd.DataFrame()

Location = r'/home/orestis/Desktop/train.csv'
df=pd.read_csv(Location)


scores=df['review_scores_rating']
all_hoods=df['neighbourhood_cleansed']
DataSet = list(zip(all_hoods,scores))


new_df=pd.DataFrame(data=DataSet,columns=['neighbourhoods','Scores'])
hoods=new_df.groupby('neighbourhoods')
new_df=hoods.sum()
new_df['Scores'].plot.bar()
print("Best review_score neighbourhoods")
new_df.sort_values(by='Scores',ascending=False)
# Out:
# Best review_score neighbourhoods
#                                     Scores
# neighbourhoods
# ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ            292791.0
# ΚΟΥΚΑΚΙ-ΜΑΚΡΥΓΙΑΝΝΗ               188233.0
# ΜΟΥΣΕΙΟ-ΕΞΑΡΧΕΙΑ-ΝΕΑΠΟΛΗ          167790.0
# ΝΕΟΣ ΚΟΣΜΟΣ                       146630.0
# ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ  118384.0
# ΠΑΓΚΡΑΤΙ                           97803.0
# ΠΛΑΤΕΙΑ ΑΤΤΙΚΗΣ                    91198.0
# ΚΟΛΩΝΑΚΙ                           81124.0
# ΑΚΡΟΠΟΛΗ                           80264.0
# ΑΜΠΕΛΟΚΗΠΟΙ                        74164.0
# ΘΗΣΕΙΟ                             69715.0
# ΠΕΤΡΑΛΩΝΑ                          59614.0
# ΚΕΡΑΜΕΙΚΟΣ                         51374.0
# ΣΤΑΔΙΟ                             50425.0
# ΚΥΨΕΛΗ                             39726.0
# ΙΛΙΣΙΑ                             38555.0
# ΖΑΠΠΕΙΟ                            27050.0
# ΛΥΚΑΒΗΤΤΟΣ                         25975.0
# ΓΟΥΔΙ                              23239.0
# ΚΟΛΩΝΟΣ                            22545.0
# ...

# %% [markdown]
# # 1.12 Map of real estates with more than 2 bedrooms

# %%
from pandas import DataFrame,read_csv

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import folium

from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')


df=pd.DataFrame()

Location = r'/home/orestis/Desktop/train.csv'
df=pd.read_csv(Location)

bedrooms=df['bedrooms']
latitude = df['latitude']
longitude = df['longitude']
all_ids = df['id']
visited_ids = []
m=folium.Map(location=[latitude[0],longitude[0]])


for i in range(0,len(latitude)):
    if(bedrooms[i]>2 and all_ids[i] not in visited_ids):
        folium.Marker(location=[latitude[i],longitude[i]]).add_to(m)
        visited_ids.append(all_ids[i])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Erotima 3(TF-IDF)
# Αποθήκευσαμε τα keywords του κάθε description+name σε ένα αρχείο ώστε να μην χρειάζετε να τα βρίσκουμε κάθε φορά

# %% [markdown]
# <h3>1. TF-IDF (Term Frequency - Inverse Document Frequency) </h3>

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity

import nltk
import os
import string
import numpy as np
import copy
import pandas as pd
import pickle
import re
import math
import re

#from IPython import get_ipython
#get_ipython().run_line_magic('matplotlib', 'inline')



def preprocess(text):
    #lowercase
    text = (str(text).lower())
    #remove tags
    text = re.sub("<!--?.*?-->","",text)
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    return text


def get_stop_words():
    return frozenset(stopwords.words('english'))



def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)



def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]
 
    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
 
    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results




df=pd.DataFrame()

Location = r'/home/orestis/EKPA/6examino/DataMining/project1/train.csv'
df=pd.read_csv(Location)

ids = df['id']
names = df['name']
descriptions = df['description']


df['text'] = df['name'] + df['description']
df['text'] = df['text'].apply(lambda x:preprocess(x))

#load a set of stop words
stopwords = get_stop_words()
#get the text column
docs = df['text'].tolist()
#create a vocabulary of words, 
#ignore words that appear in 85% of documents, 
#eliminate stop words
cv=CountVectorizer(max_df=0.85,stop_words=stopwords)
word_count_vector=cv.fit_transform(docs)

tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)
 
# you only needs to do this once, this is a mapping of index to 
feature_names=cv.get_feature_names()


keywords_list = []
# get the document that we want to extract keywords from
for doc in docs:
    #generate tf-idf for the given document
    tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))

    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    #extract only the top n; n here is 10
    keywords=extract_topn_from_vector(feature_names,sorted_items,10)
    keywords_list.append(list(keywords.keys()))

# %% [markdown]
# <h3>2.3. Cosine similarity and recommendation </h3>

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.collocations import *


import nltk
import os
import string
import numpy as np
import pandas as pd
import re
import math
import linecache
import operator


vectorizer = TfidfVectorizer()

def cosine_sim(text1, text2):
    tfidf = vectorizer.fit_transform([text1, text2])
    return ((tfidf * tfidf.T).A)[0,1]


def get_id_index(ids,id):#Get the index of the target id(index in the lists and number of line in keywords file)
    for i in range(0,len(ids)):
        if(str(ids[i])==str(id)):
            return i+1



def recommend(target_id,number):
    Location = r'/home/orestis/EKPA/6examino/DataMining/project1/train.csv'
    df=pd.read_csv(Location)

    ids = df['id']
    names = df['name']
    descriptions = df['description']

    target_index = get_id_index(ids,target_id)

    target_keywords = linecache.getline('keywords.txt',target_index)#Get the keywords of target
    cosine_sim_array = []#An aray (with cosine similarity and index) of target with all other keywords
    keywords_file = open("keywords.txt","r")
    for i in range(10):
        if i != target_index and ids[i]!=ids[target_index]:
            keywords = keywords_file.readline()
            cosine_sim_array.append((cosine_sim(target_keywords,keywords),i))#append a tuple of cosine similarity and index because we will sort valus later
        else:
            cosine_sim_array.append((0,i))

    cosine_sim_array.sort(key = operator.itemgetter(0), reverse = True)
    print('Recommending ' + str(number) + ' listings similiar to id:' + str(target_id))
    for i in range(0,number):
        index = cosine_sim_array[i][1]#get index
        score = cosine_sim_array[i][0] 
        print('Recommended:' + str(names[index]))    
        print('Description:' + str(descriptions[index]))
        print("(score:"+str(score)+")")


recommend(10595,3)
# Out:
# Recommending 3 listings similiar to id:10595
# Recommended:96m2, 3BR, 2BA, Metro, WI-FI etc...
# ...

# %% [markdown]
# <h3>4.Λέξεις που εμφανίζονται συχνά μαζί με άλλες λέξεις  (collocation)</h3>

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.collocations import *


import nltk
import os
import string
import numpy as np
import pandas as pd
import re
import math
import linecache
import operator


bigram_measures = nltk.collocations.BigramAssocMeasures()
Location = r'/home/leonidas/Desktop/datamining python ergasia1/train.csv'
df=pd.read_csv(Location)
names = df['name']
descriptions = df['description']
names = names.replace(np.nan, 'NULL') #fill NA with NULL // vali sta kena tin leksi NULL
descriptions = descriptions.replace(np.nan, 'NULL') #fill NA with NULL // vali sta kena tin leksi NULL
df = pd.concat([names,descriptions]) # connect name with descriptions
df=df.str.cat(sep=', ')#concat all rows of table to one string
tokens = nltk.wordpunct_tokenize(df) 
stop_words = stopwords.words('english')
stop_words.extend(['', 'in', 'of', '-', ',','!,','.'])
tokens = [word for word in tokens if word not in stop_words]
print(tokens)
bigramFinder=nltk.collocations.BigramCollocationFinder.from_words(tokens)
bigram_freq = bigramFinder.ngram_fd.items()
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)


print('\n')
print(bigramFreqTable.head(10))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#                     bigram   freq
# 8414      (The, apartment)  12579
# 2501        (living, room)  11573
# 1847     (fully, equipped)   8993
# 3553      (metro, station)   8089
# 2445         (double, bed)   7139
# 890    (walking, distance)   6700
# 1070      (center, Athens)   5659
# 31989  (equipped, kitchen)   5492
# 53         (heart, Athens)   5338
# 22928          (sofa, bed)   3858
